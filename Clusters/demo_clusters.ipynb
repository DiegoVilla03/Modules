# %% [markdown]
# # Demo usage clusters module

# %%
import numpy as np
import clusters as cl

# %% [markdown]
# ## Example of Usage

# %% [markdown]
# the definiton of data

# %%
means = {
    '1': np.array([0, 0, 0]),
    '2': np.array([3, 3, 3]),
    '3': np.array([0, 3, 3])
}

covariances = {
    '1': np.array([[1, 0.5, 0.3], [0.5, 1, 0.2], [0.3, 0.2, 1]]),
    '2': np.array([[1, 0.3, 0.1], [0.3, 1, 0.2], [0.1, 0.2, 1]]),
    '3': np.array([[1, 0.4, 0.2], [0.4, 1, 0.3], [0.2, 0.3, 1]])
}

samples = {
    '1': 1000,
    '2': 1500,
    '3': 2000
}

# %%
# object inicialization 
sim1 = cl.generate_clusters(means, covariances, samples)

# sample generation 
sim1.generate_samples()
# 2d ploting of data
# replace parameter lables to False for data only 
sim1.plot_2d(labels=True)

# %%
# 3d ploting of data
# replace parameter lables to False for data only 
sim1.plot_3d(labels=True)

# %%
# convert the data into a df to operate with pandas 
# Replace parameter labels to False for data only 
sample_data = sim1.to_df(labels=True)

sample_data.head()
# Out:
#                   Dim_1                Dim_2                Dim_3 Group
# 0   0.08441522821528544    0.592063510312939   1.5028863964677337     1
# 1    0.8295256237801595   1.1408302811566278  -0.5812560448140537     1
# 2    1.0507693308261863    2.026818392217865   1.0393018288486469     1
# 3  -0.10334840080786763  -0.6023525918932162  -1.2995109663249975     1
# 4  -0.23733137490226128    0.055257836883963  0.04792202687135502     1
