# %% [markdown]
# # Demo Usage network modlue

# %%
import network as net
import numpy as np

# %% [markdown]
# ## Example of usage

# %%
# definition of the number of neurons per layer
layers = np.array([24, 12, 6, 20, 10, 5, 4, 8, 22])
# construction of the neural network 
nn = net.NeuralNetwork(layers)
# ploting the neural network
# the palette parameter suports all matplotlib color maps
### https://matplotlib.org/stable/users/explain/colors/colormaps.html
nn.plot(palette='cool')

# %%
layers_1 = np.array([16, 8, 4, 8, 16])
nn1 = net.NeuralNetwork(layers_1)
nn1.plot(palette='plasma')

# %%
layers_2 = np.array([32, 16, 8, 16, 8, 4])

nn2 = net.NeuralNetwork(layers_2)

nn2.plot(palette='cividis')

# %%
layers_3 = np.array([10, 20, 10, 5])

nn3 = net.NeuralNetwork(layers_3)

nn3.plot(palette='inferno')
